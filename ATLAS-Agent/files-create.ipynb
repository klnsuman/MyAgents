# %%
import json
import os

def create_sample_files():
    """Create sample JSON files for the Academic Assistant system"""
    
    # Sample data with CORRECT structure
    sample_data = {
        "profile.json": {
            "profiles": [
                {
                    "id": "student_123",
                    "name": "Alice Johnson",
                    "email": "alice.johnson@university.edu",
                    "major": "Computer Science",
                    "year": "Junior",
                    "gpa": 3.7,
                    "courses": [
                        {
                            "code": "CS301",
                            "name": "Data Structures and Algorithms",
                            "credits": 4,
                            "professor": "Dr. Smith"
                        },
                        {
                            "code": "CS350",
                            "name": "Machine Learning",
                            "credits": 3,
                            "professor": "Dr. Chen"
                        },
                        {
                            "code": "MATH210",
                            "name": "Linear Algebra",
                            "credits": 3,
                            "professor": "Dr. Williams"
                        },
                        {
                            "code": "CS220",
                            "name": "Database Systems",
                            "credits": 3,
                            "professor": "Dr. Kumar"
                        }
                    ],
                    "interests": ["AI/ML", "Data Science", "Backend Development"],
                    "study_preferences": {
                        "preferred_time": "evening",
                        "study_duration": "2-3 hours",
                        "break_frequency": "every 45 minutes"
                    }
                }
            ]
        },
        
        "calendar.json": {
            "events": [
                {
                    "event_id": "evt001",
                    "title": "CS301 Lecture",
                    "type": "class",
                    "start": {"dateTime": "2024-12-23T09:00:00"},  # Nested structure
                    "end": {"dateTime": "2024-12-23T10:30:00"},
                    "location": "Engineering Building Room 201",
                    "recurring": "Monday, Wednesday, Friday"
                },
                {
                    "event_id": "evt002",
                    "title": "CS350 Lab",
                    "type": "class",
                    "start": {"dateTime": "2024-12-23T14:00:00"},
                    "end": {"dateTime": "2024-12-23T16:00:00"},
                    "location": "Computer Lab 3",
                    "recurring": "Monday, Wednesday"
                },
                {
                    "event_id": "evt003",
                    "title": "Study Group - Linear Algebra",
                    "type": "study_session",
                    "start": {"dateTime": "2024-12-24T18:00:00"},
                    "end": {"dateTime": "2024-12-24T20:00:00"},
                    "location": "Library Room 305",
                    "attendees": ["Bob", "Carol", "David"]
                },
                {
                    "event_id": "evt004",
                    "title": "Office Hours - Dr. Chen",
                    "type": "office_hours",
                    "start": {"dateTime": "2024-12-26T15:00:00"},
                    "end": {"dateTime": "2024-12-26T16:00:00"},
                    "location": "CS Department Room 412"
                },
                {
                    "event_id": "evt005",
                    "title": "CS350 Midterm Exam",
                    "type": "exam",
                    "start": {"dateTime": "2024-12-27T10:00:00"},
                    "end": {"dateTime": "2024-12-27T12:00:00"},
                    "location": "Exam Hall A"
                }
            ],
            "time_zone": "America/New_York"
        },
        
        "task.json": {
            "tasks": [
                {
                    "task_id": "task001",
                    "title": "CS301 Assignment 3 - Binary Search Trees",
                    "course": "CS301",
                    "type": "assignment",
                    "description": "Implement BST operations including insert, delete, search, and traversal",
                    "due": "2024-12-28T23:59:00",
                    "priority": "high",
                    "estimated_hours": 5,
                    "status": "in_progress",
                    "completion_percentage": 40
                },
                {
                    "task_id": "task002",
                    "title": "CS350 Project - CNN Implementation",
                    "course": "CS350",
                    "type": "project",
                    "description": "Build a CNN for image classification using PyTorch",
                    "due": "2025-01-05T23:59:00",
                    "priority": "high",
                    "estimated_hours": 15,
                    "status": "not_started",
                    "completion_percentage": 0,
                    "milestones": [
                        {"name": "Data preprocessing", "due": "2024-12-30"},
                        {"name": "Model architecture", "due": "2025-01-02"},
                        {"name": "Training & evaluation", "due": "2025-01-04"},
                        {"name": "Final report", "due": "2025-01-05"}
                    ]
                },
                {
                    "task_id": "task003",
                    "title": "MATH210 Problem Set 5",
                    "course": "MATH210",
                    "type": "homework",
                    "description": "Problems on eigenvalues and eigenvectors",
                    "due": "2024-12-25T17:00:00",
                    "priority": "medium",
                    "estimated_hours": 3,
                    "status": "not_started",
                    "completion_percentage": 0
                },
                {
                    "task_id": "task004",
                    "title": "CS220 Quiz Preparation",
                    "course": "CS220",
                    "type": "exam_prep",
                    "description": "Study chapters 5-7 on SQL joins and normalization",
                    "due": "2024-12-26T09:00:00",
                    "priority": "high",
                    "estimated_hours": 4,
                    "status": "in_progress",
                    "completion_percentage": 60
                },
                {
                    "task_id": "task005",
                    "title": "Read CS350 Research Paper",
                    "course": "CS350",
                    "type": "reading",
                    "description": "ResNet paper - Deep Residual Learning for Image Recognition",
                    "due": "2024-12-24T23:59:00",
                    "priority": "medium",
                    "estimated_hours": 2,
                    "status": "completed",
                    "completion_percentage": 100
                },
                {
                    "task_id": "task006",
                    "title": "CS301 Midterm Review",
                    "course": "CS301",
                    "type": "exam_prep",
                    "description": "Review all topics: arrays, linked lists, stacks, queues, trees",
                    "due": "2024-12-27T10:00:00",
                    "priority": "high",
                    "estimated_hours": 8,
                    "status": "not_started",
                    "completion_percentage": 0
                }
            ],
            "metadata": {
                "last_updated": "2024-12-21T10:00:00",
                "total_tasks": 6,
                "completed_tasks": 1,
                "pending_tasks": 5
            }
        }
    }
    
    print("=" * 60)
    print("Creating Sample JSON Files for Academic Assistant")
    print("=" * 60)
    
    # Create the files
    for filename, data in sample_data.items():
        try:
            with open(filename, 'w', encoding='utf-8') as f:
                json.dump(data, f, indent=2, ensure_ascii=False)
            
            file_size = os.path.getsize(filename)
            print(f"✓ Created {filename} ({file_size} bytes)")
            
        except Exception as e:
            print(f"✗ Error creating {filename}: {e}")
    
    print("\n" + "=" * 60)
    print("✅ All sample files created successfully!")
    print("=" * 60)
    
    print("\nFiles created in current directory:")
    print(f"Current path: {os.getcwd()}")
    
    print("\n🔧 Structure fixes:")
    print("  ✓ profile.json: 'id' field")
    print("  ✓ calendar.json: start/end with nested 'dateTime'")
    print("  ✓ task.json: 'due' field")
    
    print("\nFile list:")
    for filename in sample_data.keys():
        if os.path.exists(filename):
            print(f"  ✓ {filename}")
        else:
            print(f"  ✗ {filename} (not found)")
    
    print("\n" + "=" * 60)
    print("You can now run the Academic Assistant workflow!")
    print("=" * 60)

# Run the function
if __name__ == "__main__":
    create_sample_files()
# Out:
# ...
# Creating Sample JSON Files for Academic Assistant
# ...
# ✓ Created profile.json (1100 bytes)
# ✓ Created calendar.json (1608 bytes)
# ✓ Created task.json (2790 bytes)
#
# ...
# ✅ All sample files created successfully!
# ...
#
# Files created in current directory:
# Current path: /Users/kanderaolaxminarasimharao/Documents/Python-Code/Gen-AI/ATLAS-Agent
#
# 🔧 Structure fixes:
#   ✓ profile.json: 'id' field
#   ✓ calendar.json: start/end with nested 'dateTime'
#   ✓ task.json: 'due' field
#
# File list:
#   ✓ profile.json
#   ✓ calendar.json
#   ✓ task.json
#
# ...
# You can now run the Academic Assistant workflow!
# ...

# %%
from langchain_nvidia_ai_endpoints import ChatNVIDIA

print("Available models for your API key:")
print("=" * 60)

try:
    available = ChatNVIDIA.get_available_models()
    for i, model in enumerate(available, 1):
        print(f"{i}. {model}")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Available models for your API key:
# ...
# 1. id='meta/llama-guard-4-12b' model_type='chat' client='ChatNVIDIA' endpoint=None aliases=None supports_tools=False supports_structured_output=False supports_thinking=False base_model=None
# 2. id='meta/llama3-70b-instruct' model_type='chat' client='ChatNVIDIA' endpoint=None aliases=['ai-llama3-70b'] supports_tools=False supports_structured_output=False supports_thinking=False base_model=None
# 3. id='upstage/solar-10.7b-instruct' model_type='chat' client='ChatNVIDIA' endpoint=None aliases=['ai-solar-10_7b-instruct'] supports_tools=False supports_structured_output=False supports_thinking=False base_model=None
# 4. id='aisingapore/sea-lion-7b-instruct' model_type='chat' client='ChatNVIDIA' endpoint=None aliases=['ai-sea-lion-7b-instruct'] supports_tools=False supports_structured_output=False supports_thinking=False base_model=None
# ...

# %%
import  langchain_nvidia_ai_endpoints
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import  langchain_nvidia_ai_endpoints
#
# ModuleNotFoundError: No module named 'langchain_nvidia_ai_endpoints'

# %%
# !conda install langchain_nvidia_ai_endpoints
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# doneieving notices: -
# Channels:
#  - defaults
# Platform: osx-arm64
# doneecting package metadata (repodata.json): |
# failedg environment: -
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - langchain_nvidia_ai_endpoints
#
# Current channels:
#
#   - defaults
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
